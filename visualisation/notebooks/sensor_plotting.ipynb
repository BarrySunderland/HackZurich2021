# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
BASE_PATH="/home/barry/projects/HackZurich2021"

# %%
fpath = os.path.join(BASE_PATH,"data/processed/rssi_mean.csv") 
df = pd.read_csv(fpath)

# %%
df.shape
# Out:
# (10028163, 9)

# %%
df.head()
# Out:
#          Date  PositionNoLeap   Latitude  Longitude  A1_TotalTel  A1_ValidTel  \
# 0  2021-01-09          322075  47.310370   8.114984    1754745.0    1731249.0
# 1  2021-01-09          322154  47.310308   8.115033    1754750.0    1731254.0
# 2  2021-01-09          322227  47.310248   8.115072    1754755.0    1731259.0
# 3  2021-01-09          322292  47.310194   8.115106    1754760.0    1731264.0
# 4  2021-01-09          322351  47.310145   8.115134    1754764.0    1731268.0
#
#    A2_RSSI  A2_TotalTel  A2_ValidTel
# 0     2.09    1553797.0    1549606.0
# 1     1.99    1553802.0    1549611.0
# 2     2.05    1553807.0    1549616.0
# 3     2.06    1553812.0    1549621.0
# 4     1.75    1553816.0    1549625.0

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
df
# Out:
#             PositionNoLeap   Latitude  Longitude  A1_TotalTel  A1_ValidTel  \
# Date
# 2021-01-09          322075  47.310370   8.114984    1754745.0    1731249.0
# 2021-01-09          322154  47.310308   8.115033    1754750.0    1731254.0
# 2021-01-09          322227  47.310248   8.115072    1754755.0    1731259.0
# 2021-01-09          322292  47.310194   8.115106    1754760.0    1731264.0
# 2021-01-09          322351  47.310145   8.115134    1754764.0    1731268.0
# ...                    ...        ...        ...          ...          ...
# 2021-06-25          102202  47.309015   8.050810      78320.0      78320.0
# 2021-06-25          102219  47.309030   8.050816      78325.0      78325.0
# 2021-06-25          102228  47.309037   8.050820      78330.0      78330.0
# 2021-06-25          102233  47.309042   8.050823      78334.0      78334.0
# 2021-06-25          102234  47.309042   8.050823      78439.5      78439.5
#
#              A2_RSSI  A2_TotalTel  A2_ValidTel
# Date
# ...

# %%
plt.style.use('ggplot')
fig,ax = plt.subplots(figsize=(12,12))
ax = tser.plot(kind='line',linewidth=5, c='blue')
plt.ylabel('rssi_mean', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.title("rssi_mean value at position 322,227", fontsize=32)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.tight_layout()
ax.label_size=16
fig.savefig("./rssi_mean vs date")
plt.show()

# %%
fltr = df['PositionNoLeap'] == 322227
tser = df.loc[fltr,'A2_RSSI']


ax = plt.plot(tser.index, tser.values)


plt.show()

# %%
df
# Out:
#             PositionNoLeap   Latitude  Longitude  A1_TotalTel  A1_ValidTel  \
# Date
# 2021-01-09          322075  47.310370   8.114984    1754745.0    1731249.0
# 2021-01-09          322154  47.310308   8.115033    1754750.0    1731254.0
# 2021-01-09          322227  47.310248   8.115072    1754755.0    1731259.0
# 2021-01-09          322292  47.310194   8.115106    1754760.0    1731264.0
# 2021-01-09          322351  47.310145   8.115134    1754764.0    1731268.0
# ...                    ...        ...        ...          ...          ...
# 2021-06-25          102202  47.309015   8.050810      78320.0      78320.0
# 2021-06-25          102219  47.309030   8.050816      78325.0      78325.0
# 2021-06-25          102228  47.309037   8.050820      78330.0      78330.0
# 2021-06-25          102233  47.309042   8.050823      78334.0      78334.0
# 2021-06-25          102234  47.309042   8.050823      78439.5      78439.5
#
#              A2_RSSI  A2_TotalTel  A2_ValidTel
# Date
# ...

# %%
df['PositionNoLeap'].unique().shape
# Out:
# (330332,)

# %%
lat = 47.310248
lon = 8.115072

url = f"https://www.google.com/maps/@{lat},{lon},3a,75y,239.53h,90t/data=!3m8!1e1!3m6!1sAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI!2e10!3e11!6shttps:%2F%2Flh5.googleusercontent.com%2Fp%2FAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI%3Dw203-h100-k-no-pi3.9780064-ya84.495674-ro0.73092246-fo100!7i5120!8i2560"

print(url)
# Out:
# https://www.google.com/maps/@47.310248,8.115072,3a,75y,239.53h,90t/data=!3m8!1e1!3m6!1sAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI!2e10!3e11!6shttps:%2F%2Flh5.googleusercontent.com%2Fp%2FAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI%3Dw203-h100-k-no-pi3.9780064-ya84.495674-ro0.73092246-fo100!7i5120!8i2560

# %%
lat = 47.309030
lon = 8.050810

url = f"https://www.google.com/maps/@{lat},{lon},3a,75y,239.53h,90t/data=!3m8!1e1!3m6!1sAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI!2e10!3e11!6shttps:%2F%2Flh5.googleusercontent.com%2Fp%2FAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI%3Dw203-h100-k-no-pi3.9780064-ya84.495674-ro0.73092246-fo100!7i5120!8i2560"

print(f"{lat},{lon}")

print(url)
# Out:
# 47.30903,8.05081
# https://www.google.com/maps/@47.30903,8.05081,3a,75y,239.53h,90t/data=!3m8!1e1!3m6!1sAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI!2e10!3e11!6shttps:%2F%2Flh5.googleusercontent.com%2Fp%2FAF1QipPAQiZHuv-2bC97UPMln71fvXRhMUwAg4iZCwOI%3Dw203-h100-k-no-pi3.9780064-ya84.495674-ro0.73092246-fo100!7i5120!8i2560

# %%
url = f"https://earth.google.com/web/search/{lat},{lon}"
print(url)
# Out:
# https://earth.google.com/web/search/47.30903,8.05081

# %%
df.columns
# Out:
# Index(['PositionNoLeap', 'Latitude', 'Longitude', 'A1_TotalTel', 'A1_ValidTel',
#        'A2_RSSI', 'A2_TotalTel', 'A2_ValidTel'],
#       dtype='object')
