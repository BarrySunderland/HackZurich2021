# %%
import os
import pandas as pd

# %%
input_dir = "../data/raw"

# %%
csvs = [f for f in os.listdir(input_dir) if f.endswith(".csv")]
csvs
# Out:
# ['velocities.csv',
#  'events.csv',
#  'disruptions.csv',
#  'rssi.csv',
#  'Mapping_Events_Disruptions.csv']

# %%
i=0
fpath = os.path.join(input_dir, csvs[i])
df = pd.read_csv(fpath, nrows=1000)
print(csvs[i])
df
# Out:
# velocities.csv
#            ID             DateTime  CurrentVelocity  AllowedVelocity  \
# 0    19642270  2020-01-22 00:00:01                0                0
# 1    19642271  2020-01-22 00:00:02                0                0
# 2    19642272  2020-01-22 00:00:03                0                0
# 3    19642273  2020-01-22 00:00:04                0                0
# 4    19642274  2020-01-22 00:00:05                0                0
# ..        ...                  ...              ...              ...
# 995  19643265  2020-01-22 04:33:35                0                0
# 996  19643266  2020-01-22 04:33:36                0                0
# 997  19643267  2020-01-22 04:33:37                0                0
# 998  19643268  2020-01-22 04:33:38                0                0
# 999  19643269  2020-01-22 04:33:39                0                0
#
#      EmergencyStopLimit
# 0                     0
# 1                     0
# 2                     0
# ...

# %%
i=1
fpath = os.path.join(input_dir, csvs[i])
df = pd.read_csv(fpath, nrows=1000)
print(csvs[i])
df
# Out:
# events.csv
#        ID             DateTime   EventCode  \
# 0     352  2020-01-22 04:22:15  1698873063
# 1     353  2020-01-22 04:23:11   977419008
# 2     354  2020-01-22 09:52:49   977419008
# 3     355  2020-01-22 09:55:37  1698873063
# 4     356  2020-01-22 10:03:11  1698873063
# ..    ...                  ...         ...
# 995  1364  2020-02-25 06:57:09   977419008
# 996  1365  2020-02-25 08:05:47   711767840
# 997  1366  2020-02-25 16:35:42   711767840
# 998  1367  2020-02-25 16:35:59  1698873082
# 999  1368  2020-02-25 16:36:04   559684160
#
#                                            Description
# 0                     Zwangsbremsung | Initialisierung
# 1    Zugdaten bestaetigt: | Zuglaenge [dm]: 410 | B...
# 2    Zugdaten bestaetigt: | Zuglaenge [dm]: 410 | B...
# 3                     Zwangsbremsung | Initialisierung
# 4                     Zwangsbremsung | Initialisierung
# ..                                                 ...
# ...

# %%
i=2
fpath = os.path.join(input_dir, csvs[i])
df = pd.read_csv(fpath, nrows=1000, )
print(csvs[i])
df
# Out:
# disruptions.csv
#        ID             DateTime  DisruptionCode  \
# 0       1  2020-02-08 04:37:25       960862267
# 1       2  2020-02-08 04:41:39       960862267
# 2       3  2020-02-08 08:06:31       960862267
# 3       4  2020-02-08 16:18:53       960862267
# 4       5  2020-02-10 03:06:12       960862267
# ..    ...                  ...             ...
# 995  2090  2020-09-22 17:50:36       960862267
# 996  2091  2020-09-22 18:41:16       960862258
# 997  2092  2020-09-22 20:09:25       960862258
# 998  2093  2020-09-22 21:54:25       960862258
# 999  2094  2020-09-23 04:11:15       960862267
#
#                                 Description
# 0    Stoerung: Zwangsbremse wurde aktiviert
# 1    Stoerung: Zwangsbremse wurde aktiviert
# 2    Stoerung: Zwangsbremse wurde aktiviert
# 3    Stoerung: Zwangsbremse wurde aktiviert
# 4    Stoerung: Zwangsbremse wurde aktiviert
# ..                                      ...
# 995            Zwangsbremse wurde aktiviert
# ...

# %%
i=3
fpath = os.path.join(input_dir, csvs[i])
df = pd.read_csv(fpath, nrows=1000)
print(csvs[i])
df
# Out:
# rssi.csv
#        ID             DateTime  AreaNumber  Track  Position  PositionNoLeap  \
# 0       1  2021-01-09 00:00:01          33      1    315325          322075
# 1       2  2021-01-09 00:00:02          33      1    315404          322154
# 2       3  2021-01-09 00:00:03          33      1    315477          322227
# 3       4  2021-01-09 00:00:04          33      1    315542          322292
# 4       5  2021-01-09 00:00:05          33      1    315601          322351
# ..    ...                  ...         ...    ...       ...             ...
# 995   996  2021-01-09 00:16:36          40      1    411121          417871
# 996   997  2021-01-09 00:16:37          40      1    411237          417987
# 997   998  2021-01-09 00:16:38          40      1    411356          418106
# 998   999  2021-01-09 00:16:39          40      1    411479          418229
# 999  1000  2021-01-09 00:16:40          40      1    411606          418356
#
# ...

# %%
i=4
fpath = os.path.join(input_dir, csvs[i])
df = pd.read_csv(fpath, nrows=1000)
print(csvs[i])
df.sort_values(by='RelevantForChallenge')
# Out:
# Mapping_Events_Disruptions.csv
#     ID  EventDisruptionCode  \
# 0    1            960862267
# 1    2            960862267
# 2    3            960862258
# 3    4            960862258
# 36  37           1698873056
# 45  46           1698873074
# 46  47           1698873079
# 4    5            960862257
# 5    6            960862257
# 6    7            960862268
# 7    8            960862268
# 8    9            960862244
# 9   10            960862249
# 10  11           1238445441
# 11  12            559626400
# 12  13            559665728
# 13  14            559665728
# 14  15            559684160
# 15  16            559684160
# 16  17            559694208
# 17  18            559694208
# 18  19            640730272
# 19  20            640730272
# 20  21            650969632
# 21  22            653635684
# 22  23            653635687
# 23  24            653635687
# 24  25            653808096
# 25  26            653808096
# 26  27            693258176
# 27  28            711767840
# ...
